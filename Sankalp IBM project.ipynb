# %% [markdown]
#  # My Jupyter Notebook on IBM Watson Studio

# %% [markdown]
# My name is __Sankalp Bolisetti__
# I am currently working as a quality analyst

# %% [markdown]
# _I am interested in data science because I like to play with data_

# %% [markdown]
# ### I am going to write a code to print "Welcome to Data Sacience"

# %%
print("Welcome To Data Science")
# Out:
# Welcome To Data Science

# %% [markdown]
# *** Horizontal rule
# - bulleted item
# 1. Numbered item
